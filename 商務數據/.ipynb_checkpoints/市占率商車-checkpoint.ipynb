# %%
import pandas as pd
import seaborn as sns
import datetime
import time
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import StandardScaler
import numpy as np
from pmdarima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
df = pd.read_csv(r'/Users/xuzhejia/Desktop/商務數據/cmc_2.csv')
# Out:
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
group = df.groupby(['year','month','type2'])
group_year = []
group_month = []
group_sum = []
group_oil = []
group_steel = []
group_CPI = []
group_CPIT = []
group_economicgrowth = []
group_gdp = []
group_incomeaverage = []
group_covid = []
group_industry = []
group_stock = []
group_type = []
group_signal = []
group_lead = []
for x,y in group:
    group_year.append(list(group.get_group(x)['year'])[0])
    group_month.append(list(group.get_group(x)['month'])[0])
    group_sum.append(group.get_group(x)['number'].sum())
    group_oil.append(list(group.get_group(x)['oil'])[0])
    group_steel.append(list(group.get_group(x)['steel'])[0])
    group_CPI.append(list(group.get_group(x)['CPI'])[0])
    group_CPIT.append(list(group.get_group(x)['CPIT'])[0])
    group_economicgrowth.append(list(group.get_group(x)['economicgrowth'])[0])
    group_gdp.append(list(group.get_group(x)['gdp'])[0])
    group_incomeaverage.append(list(group.get_group(x)['income average'])[0])
    group_covid.append(list(group.get_group(x)['covid'])[0])
    group_industry.append(list(group.get_group(x)['industry'])[0])
    group_stock.append(list(group.get_group(x)['stock'])[0])
    group_type.append(list(group.get_group(x)['type2'])[0])
    group_signal.append(list(group.get_group(x)['signal'])[0])
    group_lead.append(list(group.get_group(x)['lead'])[0])

# %%
df_groupby = pd.DataFrame([group_year,group_month,group_sum,group_oil,group_steel,group_CPI,group_CPIT,group_economicgrowth,group_gdp,group_incomeaverage,
group_covid,group_industry,group_stock,group_signal,group_lead,group_type]).T
df_groupby.columns = ['year','month','sum','oil','steel','CPI','CPIT','economicgrowth','gdp','incomeaverage','covid','industry','stock','signal','lead','type']

# %%
df_groupby['year'] = df_groupby['year'].astype(str)
df_groupby['month'] = df_groupby['month'].astype(str)
df_groupby['year'] = df_groupby['year'].apply(lambda x:x.replace('.0',""))
df_groupby['month'] = df_groupby['month'].apply(lambda x:x.replace('.0',""))

# %%
df_groupby['date'] = df_groupby['year'] +'/' + df_groupby['month']
df_groupby
# Out:
#      year month    sum     oil   steel     CPI    CPIT economicgrowth  \
# 0    2012     1  13475  110.63   24000   96.37  106.78           1.09
# 1    2012     1   3050  110.63   24000   96.37  106.78           1.09
# 2    2012     1  23609  110.63   24000   96.37  106.78           1.09
# 3    2012     2   7692  122.68   24000   95.09  106.86           1.09
# 4    2012     2   2155  122.68   24000   95.09  106.86           1.09
# ..    ...   ...    ...     ...     ...     ...     ...            ...
# 364  2022     2   3025  103.07  29,979  106.02  107.96           3.06
# 365  2022     2   7073  103.07  29,979  106.02  107.96           3.06
# 366  2022     3  21228  114.87  29,979     NaN     NaN            NaN
# 367  2022     3   4778  114.87  29,979     NaN     NaN            NaN
# 368  2022     3  12154  114.87  29,979     NaN     NaN            NaN
#
#            gdp incomeaverage covid industry     stock signal   lead type  \
# 0    3573234.0      133393.0   0.0    78.08   7517.08   13.0   89.4  RV車
# 1    3573234.0      133393.0   0.0    78.08   7517.08   13.0   89.4   商車
# 2    3573234.0      133393.0   0.0    78.08   7517.08   13.0   89.4   轎車
# 3    3573234.0      133393.0   0.0    84.12   8121.44   15.0  90.18  RV車
# 4    3573234.0      133393.0   0.0    84.12   8121.44   15.0  90.18   商車
# ..         ...           ...   ...      ...       ...    ...    ...  ...
# 364        NaN           NaN   NaN      NaN  17652.18    NaN    NaN   商車
# 365        NaN           NaN   NaN      NaN  17652.18    NaN    NaN   轎車
# 366        NaN           NaN   NaN      NaN  17693.47    NaN    NaN  RV車
# 367        NaN           NaN   NaN      NaN  17693.47    NaN    NaN   商車
# 368        NaN           NaN   NaN      NaN  17693.47    NaN    NaN   轎車
#
#        date
# 0    2012/1
# 1    2012/1
# 2    2012/1
# 3    2012/2
# 4    2012/2
# ..      ...
# 364  2022/2
# 365  2022/2
# 366  2022/3
# 367  2022/3
# 368  2022/3
#
# [369 rows x 17 columns]

# %%
df_groupby.set_index(pd.to_datetime(df_groupby['date'],format = '%Y/%m'),inplace = True)
df_groupby
# Out:
#             year month    sum     oil   steel     CPI    CPIT economicgrowth  \
# date
# 2012-01-01  2012     1  13475  110.63   24000   96.37  106.78           1.09
# 2012-01-01  2012     1   3050  110.63   24000   96.37  106.78           1.09
# 2012-01-01  2012     1  23609  110.63   24000   96.37  106.78           1.09
# 2012-02-01  2012     2   7692  122.68   24000   95.09  106.86           1.09
# 2012-02-01  2012     2   2155  122.68   24000   95.09  106.86           1.09
# ...          ...   ...    ...     ...     ...     ...     ...            ...
# 2022-02-01  2022     2   3025  103.07  29,979  106.02  107.96           3.06
# 2022-02-01  2022     2   7073  103.07  29,979  106.02  107.96           3.06
# 2022-03-01  2022     3  21228  114.87  29,979     NaN     NaN            NaN
# 2022-03-01  2022     3   4778  114.87  29,979     NaN     NaN            NaN
# 2022-03-01  2022     3  12154  114.87  29,979     NaN     NaN            NaN
#
#                   gdp incomeaverage covid industry     stock signal   lead  \
# date
# 2012-01-01  3573234.0      133393.0   0.0    78.08   7517.08   13.0   89.4
# 2012-01-01  3573234.0      133393.0   0.0    78.08   7517.08   13.0   89.4
# 2012-01-01  3573234.0      133393.0   0.0    78.08   7517.08   13.0   89.4
# 2012-02-01  3573234.0      133393.0   0.0    84.12   8121.44   15.0  90.18
# 2012-02-01  3573234.0      133393.0   0.0    84.12   8121.44   15.0  90.18
# ...               ...           ...   ...      ...       ...    ...    ...
# 2022-02-01        NaN           NaN   NaN      NaN  17652.18    NaN    NaN
# 2022-02-01        NaN           NaN   NaN      NaN  17652.18    NaN    NaN
# 2022-03-01        NaN           NaN   NaN      NaN  17693.47    NaN    NaN
# 2022-03-01        NaN           NaN   NaN      NaN  17693.47    NaN    NaN
# 2022-03-01        NaN           NaN   NaN      NaN  17693.47    NaN    NaN
#
#            type    date
# date
# 2012-01-01  RV車  2012/1
# 2012-01-01   商車  2012/1
# 2012-01-01   轎車  2012/1
# 2012-02-01  RV車  2012/2
# 2012-02-01   商車  2012/2
# ...         ...     ...
# 2022-02-01   商車  2022/2
# 2022-02-01   轎車  2022/2
# 2022-03-01  RV車  2022/3
# 2022-03-01   商車  2022/3
# 2022-03-01   轎車  2022/3
#
# [369 rows x 17 columns]

# %%
df_groupby['steel'] = df_groupby['steel'].astype(str).apply(lambda x:x.replace(",",'')).astype(float)

# %%
#標準化
sc = StandardScaler()
df_groupby['oil_sc'] = sc.fit_transform(df_groupby['oil'].values.reshape(-1,1))
df_groupby['steel_sc'] = sc.fit_transform(df_groupby['steel'].values.reshape(-1,1))
df_groupby['CPI_sc'] = sc.fit_transform(df_groupby['CPI'].values.reshape(-1,1))
df_groupby['CPIT_sc'] = sc.fit_transform(df_groupby['CPIT'].values.reshape(-1,1))
df_groupby['economicgrowth_sc'] = sc.fit_transform(df_groupby['CPIT'].values.reshape(-1,1))
df_groupby['gdp_sc'] = sc.fit_transform(df_groupby['gdp'].values.reshape(-1,1))
df_groupby['incomeaverage_sc'] = sc.fit_transform(df_groupby['incomeaverage'].values.reshape(-1,1))
df_groupby['covid_sc'] = sc.fit_transform(df_groupby['covid'].values.reshape(-1,1))
df_groupby['industry_sc'] = sc.fit_transform(df_groupby['industry'].values.reshape(-1,1))
df_groupby['stock_sc'] = sc.fit_transform(df_groupby['stock'].values.reshape(-1,1))
df_groupby['signal_sc'] = sc.fit_transform(df_groupby['signal'].values.reshape(-1,1))
df_groupby['lead_sc'] = sc.fit_transform(df_groupby['lead'].values.reshape(-1,1))

# %%
df_groupby = df_groupby.loc['2012-01-01':'2020-12-01',:]

# %%
df_groupby_商車 = df_groupby[df_groupby['type'] == '商車']

# %%
plt.plot(df_groupby_商車.index,df_groupby_商車['sum'])

# %%
adfuller(df_groupby_商車['sum'].diff()[1:]) #一街差分定太
# Out:
# (-6.850750384831774,
#  1.696773012381638e-09,
#  10,
#  96,
#  {'1%': -3.5003788874873405,
#   '5%': -2.8921519665075235,
#   '10%': -2.5830997960069446},
#  1375.1074885755693)

# %%
df_model_商車 = df_groupby_商車.loc[:,['sum','oil_sc','steel_sc','CPI_sc','CPIT_sc','economicgrowth_sc','gdp_sc',
'incomeaverage_sc','covid_sc','industry_sc','stock_sc','signal_sc','lead_sc']]

# %%
df_model_商車['oil_sc_last_month'] = df_model_商車['oil_sc'].shift()
df_model_商車['steel_sc_last_month'] = df_model_商車['steel_sc'].shift()
df_model_商車['CPI_sc_last_month'] = df_model_商車['CPI_sc'].shift()
df_model_商車['economicgrowth_sc_last_month'] = df_model_商車['economicgrowth_sc'].shift()
df_model_商車['gdp_sc_last_month'] = df_model_商車['gdp_sc'].shift()
df_model_商車['incomeaverage_sc_last_month'] = df_model_商車['incomeaverage_sc'].shift()
df_model_商車['covid_sc_last_month'] = df_model_商車['covid_sc'].shift()
df_model_商車['industry_sc_last_month'] = df_model_商車['industry_sc'].shift()
df_model_商車['stock_sc_last_month'] = df_model_商車['stock_sc'].shift()
df_model_商車['CPIT_sc_last_month'] = df_model_商車['CPIT_sc'].shift()
df_model_商車['last_sell'] = df_model_商車['sum'].shift()
df_model_商車['signal_sc_last_month'] = df_model_商車['signal_sc'].shift()
df_model_商車['lead_sc_last_month'] = df_model_商車['lead_sc'].shift()

# %%
#將第一列的空值排除
df_model_商車 = df_model_商車.iloc[1:,:]

# %%
result = seasonal_decompose(df_model_商車['sum'],model='additive', period=12)
rcParams['figure.figsize'] = 10, 5
result.plot()
plt.figure(figsize=(40,10))
plt.show()

# %%
#build model
auto_arima(df_groupby_商車['sum'].diff()[1:],seasonal=True,m =13,stepwise = True,max_p = 3).summary() #12
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  107
# Model:             SARIMAX(1, 0, 1)x(1, 0, [], 13)   Log Likelihood                -809.514
# Date:                             Sat, 14 May 2022   AIC                           1627.029
# Time:                                     15:30:45   BIC                           1637.720
# Sample:                                          0   HQIC                          1631.363
#                                              - 107
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2640      0.142     -1.862      0.063      -0.542       0.014
# ma.L1         -0.7858      0.070    -11.164      0.000      -0.924      -0.648
# ar.S.L13      -0.2212      0.138     -1.607      0.108      -0.491       0.049
# sigma2       2.14e+05   3.63e+04      5.891      0.000    1.43e+05    2.85e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.11   Jarque-Bera (JB):                 2.20
# Prob(Q):                              0.74   Prob(JB):                         0.33
# Heteroskedasticity (H):               2.24   Skew:                            -0.27
# Prob(H) (two-sided):                  0.02   Kurtosis:                         2.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# 10210112
ans_ans = []
for x in range(70,len(df_model_商車.index)-1):  #4
    s = SARIMAX(
                df_model_商車.loc[:df_model_商車.index[x],'sum'].astype(int).values,
                order = (1,0,1),
                seasonal_order=(1,1,1,12),
                exog = df_model_商車.loc[:df_model_商車.index[x],[                                
                                    'CPI_sc_last_month',
                                    'last_sell',
                                    'stock_sc_last_month',
                                    'incomeaverage_sc_last_month']].astype(float),
                trend = 'ct',
                time_varying_regression=False,
                mle_regression=False,
                measurement_error = True,
                enforce_stationary = False
            )
    result = s.fit()
    ans = result.get_forecast(steps = 1, exog = df_model_商車.loc[df_model_商車.index[x+1],[
                                 'CPI_sc_last_month',
                                 'last_sell',
                                 'stock_sc_last_month',
                                 'incomeaverage_sc_last_month']].astype(float))
    ans_ans.append(ans.predicted_mean.values[0])
# Out:
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.69020D+00    |proj g|=  4.41777D-02
#
# At iterate    5    f=  5.65022D+00    |proj g|=  8.31011D-03
#
# At iterate   10    f=  5.64909D+00    |proj g|=  1.77314D-03
#
# At iterate   15    f=  5.64718D+00    |proj g|=  3.75075D-02
#
# At iterate   20    f=  5.64637D+00    |proj g|=  1.62186D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     24     96      1     0     0   3.271D-01   5.646D+00
#   F =   5.6463703910342842
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.71522D+00    |proj g|=  6.57868D-02
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.66545D+00    |proj g|=  1.88909D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   10    f=  5.66449D+00    |proj g|=  4.36347D-02
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     14     73      2     0     0   8.977D-02   5.664D+00
#   F =   5.6644796277837832
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.77759D+00    |proj g|=  1.03696D-01
#
# At iterate    5    f=  5.71785D+00    |proj g|=  1.25504D-02
#
# At iterate   10    f=  5.70255D+00    |proj g|=  2.26644D-02
#   ys=-3.568E-06  -gs= 5.343E-07 BFGS update SKIPPED
#
# At iterate   15    f=  5.69933D+00    |proj g|=  4.82307D-03
#
# At iterate   20    f=  5.69833D+00    |proj g|=  7.67542D-03
#
# At iterate   25    f=  5.69687D+00    |proj g|=  6.26290D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     26    120      2     1     0   6.263D-02   5.697D+00
#   F =   5.6968739625242426
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.81519D+00    |proj g|=  9.71767D-02
#
# At iterate    5    f=  5.74184D+00    |proj g|=  1.63630D-02
#
# At iterate   10    f=  5.72564D+00    |proj g|=  2.16361D-02
#
# At iterate   15    f=  5.71932D+00    |proj g|=  4.68897D-03
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     19     80      2     0     0   3.500D-02   5.719D+00
#   F =   5.7193116684793823
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.81812D+00    |proj g|=  1.01484D-01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8      2     19      1     0     0   3.856D-02   5.795D+00
#   F =   5.7948514306082277
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.82848D+00    |proj g|=  1.07200D-01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.77867D+00    |proj g|=  4.37916D-03
#
# At iterate   10    f=  5.76418D+00    |proj g|=  3.25350D-02
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     12     40      1     0     0   4.196D-02   5.764D+00
#   F =   5.7640106059115537
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.82065D+00    |proj g|=  3.50153D-02
#
# At iterate    5    f=  5.78514D+00    |proj g|=  5.28230D-02
#
# At iterate   10    f=  5.78074D+00    |proj g|=  4.99836D-03
#
# At iterate   15    f=  5.78015D+00    |proj g|=  4.02808D-03
#
# At iterate   20    f=  5.77990D+00    |proj g|=  4.80835D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     20     75      1     0     0   4.808D-02   5.780D+00
#   F =   5.7798957982031336
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.83164D+00    |proj g|=  3.07900D-02
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.79601D+00    |proj g|=  4.39127D-02
#
# At iterate   10    f=  5.79148D+00    |proj g|=  6.68511D-03
#
# At iterate   15    f=  5.79132D+00    |proj g|=  3.89617D-03
#
# At iterate   20    f=  5.79121D+00    |proj g|=  3.13999D-03
#
# At iterate   25    f=  5.79096D+00    |proj g|=  2.82278D-02
#   ys=-1.079E-11  -gs= 1.637E-08 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     27     93      1     1     0   2.823D-02   5.791D+00
#   F =   5.7909571606049548
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.85469D+00    |proj g|=  6.42410D-02
#
# At iterate    5    f=  5.83197D+00    |proj g|=  1.12726D-02
#
# At iterate   10    f=  5.80948D+00    |proj g|=  1.18451D-02
#
# At iterate   15    f=  5.80761D+00    |proj g|=  1.94002D-03
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   20    f=  5.80757D+00    |proj g|=  2.41014D-02
#   ys=-5.719E-08  -gs= 5.510E-07 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     24    104      2     1     0   4.900D-02   5.808D+00
#   F =   5.8075675946859207
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.86544D+00    |proj g|=  5.29561D-02
#
# At iterate    5    f=  5.84573D+00    |proj g|=  1.00270D-02
#
# At iterate   10    f=  5.82243D+00    |proj g|=  2.29303D-02
#
# At iterate   15    f=  5.82143D+00    |proj g|=  4.28975D-03
#
# At iterate   20    f=  5.82048D+00    |proj g|=  5.42925D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     23     85      1     0     0   5.423D-02   5.820D+00
#   F =   5.8204779146020256
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.87593D+00    |proj g|=  5.09199D-02
#
# At iterate    5    f=  5.85551D+00    |proj g|=  8.77996D-03
#
# At iterate   10    f=  5.83111D+00    |proj g|=  8.14964D-02
#
# At iterate   15    f=  5.83101D+00    |proj g|=  7.92003D-02
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     16     55      1     0     0   7.920D-02   5.831D+00
#   F =   5.8310091158265509
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.88750D+00    |proj g|=  6.22341D-02
#
# At iterate    5    f=  5.86680D+00    |proj g|=  7.97283D-03
#
# At iterate   10    f=  5.84726D+00    |proj g|=  3.90794D-02
#
# At iterate   15    f=  5.84338D+00    |proj g|=  2.72498D-03
#
# At iterate   20    f=  5.84177D+00    |proj g|=  3.55171D-03
#
# At iterate   25    f=  5.84176D+00    |proj g|=  8.91891D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     26     68      1     0     0   8.919D-02   5.842D+00
#   F =   5.8417576868200856
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.90240D+00    |proj g|=  3.12295D-02
#
# At iterate    5    f=  5.86911D+00    |proj g|=  4.00781D-02
#
# At iterate   10    f=  5.86484D+00    |proj g|=  5.47126D-02
#
# At iterate   15    f=  5.86377D+00    |proj g|=  1.19802D-02
#
# At iterate   20    f=  5.86281D+00    |proj g|=  6.89359D-03
#
# At iterate   25    f=  5.86239D+00    |proj g|=  2.87207D-02
#
# At iterate   30    f=  5.86198D+00    |proj g|=  1.64845D-01
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   35    f=  5.86181D+00    |proj g|=  2.62852D-02
#
# At iterate   40    f=  5.86172D+00    |proj g|=  8.00778D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     40    166      2     0     0   8.008D-02   5.862D+00
#   F =   5.8617178403533252
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.90951D+00    |proj g|=  2.64073D-02
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.90011D+00    |proj g|=  6.87117D-03
#
# At iterate   10    f=  5.87382D+00    |proj g|=  2.15142D-02
#
# At iterate   15    f=  5.87256D+00    |proj g|=  3.94307D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     15     60      1     0     0   3.943D-02   5.873D+00
#   F =   5.8725605144004307
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.93309D+00    |proj g|=  3.02449D-02
#
# At iterate    5    f=  5.92017D+00    |proj g|=  3.70225D-03
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate   10    f=  5.89993D+00    |proj g|=  3.64775D-02
#
# At iterate   15    f=  5.88960D+00    |proj g|=  1.13186D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     18     85      1     0     0   1.777D-01   5.890D+00
#   F =   5.8895907122162781
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.96435D+00    |proj g|=  1.86842D-01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.96405D+00    |proj g|=  1.66406D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8      7     53      1     0     0   2.043D-01   5.964D+00
#   F =   5.9640489876250253
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.97322D+00    |proj g|=  3.20390D-02
#
# At iterate    5    f=  5.93969D+00    |proj g|=  1.56004D-02
#
# At iterate   10    f=  5.93783D+00    |proj g|=  5.25184D-03
#
# At iterate   15    f=  5.93751D+00    |proj g|=  3.29738D-03
#   ys=-3.865E-04  -gs= 2.248E-05 BFGS update SKIPPED
#
# At iterate   20    f=  5.93750D+00    |proj g|=  2.91781D-03
#
# At iterate   25    f=  5.93744D+00    |proj g|=  2.85233D-02
#   ys=-2.387E-03  -gs= 1.323E-04 BFGS update SKIPPED
#
# At iterate   30    f=  5.92904D+00    |proj g|=  1.75682D-02
#
# At iterate   35    f=  5.92171D+00    |proj g|=  2.99861D-02
#
# At iterate   40    f=  5.91634D+00    |proj g|=  1.62173D-02
#
# At iterate   45    f=  5.91245D+00    |proj g|=  7.18546D-03
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate   50    f=  5.91172D+00    |proj g|=  1.32640D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50    141      1     2     0   1.326D-01   5.912D+00
#   F =   5.9117233184296216
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.98431D+00    |proj g|=  2.27044D-02
#
# At iterate    5    f=  5.95047D+00    |proj g|=  3.14492D-02
#
# At iterate   10    f=  5.94606D+00    |proj g|=  2.44357D-03
#
# At iterate   15    f=  5.94595D+00    |proj g|=  4.25998D-02
#
# At iterate   20    f=  5.94572D+00    |proj g|=  9.41998D-03
#
# At iterate   25    f=  5.92823D+00    |proj g|=  4.17670D-02
#
# At iterate   30    f=  5.92407D+00    |proj g|=  1.20929D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     31     73      1     0     0   1.260D-01   5.924D+00
#   F =   5.9240679947926216
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.99712D+00    |proj g|=  2.50873D-02
#
# At iterate    5    f=  5.95629D+00    |proj g|=  7.82954D-03
#
# At iterate   10    f=  5.95608D+00    |proj g|=  2.29557D-02
#
# At iterate   15    f=  5.95560D+00    |proj g|=  4.93226D-03
#
# At iterate   20    f=  5.94428D+00    |proj g|=  3.52441D-02
#
# At iterate   25    f=  5.93795D+00    |proj g|=  3.30527D-01
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     29    134      2     0     0   6.089D-01   5.937D+00
#   F =   5.9373736177927805
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.01648D+00    |proj g|=  2.68006D-02
#
# At iterate    5    f=  5.97952D+00    |proj g|=  4.74690D-03
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate   10    f=  5.97886D+00    |proj g|=  6.42321D-04
#
# At iterate   15    f=  5.97864D+00    |proj g|=  3.88704D-03
#
# At iterate   20    f=  5.97476D+00    |proj g|=  1.33595D-02
#
# At iterate   25    f=  5.96753D+00    |proj g|=  7.05194D-03
#
# At iterate   30    f=  5.96175D+00    |proj g|=  1.57038D-01
#
# At iterate   35    f=  5.96127D+00    |proj g|=  3.71796D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     35     67      1     0     0   3.718D-03   5.961D+00
#   F =   5.9612655477183223
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.07222D+00    |proj g|=  4.34588D-02
#
# At iterate    5    f=  6.02684D+00    |proj g|=  1.73124D-02
#
# At iterate   10    f=  6.02361D+00    |proj g|=  5.77685D-03
#
# At iterate   15    f=  6.02292D+00    |proj g|=  4.78186D-03
#   ys=-1.493E-05  -gs= 1.554E-07 BFGS update SKIPPED
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   20    f=  6.02269D+00    |proj g|=  5.29296D-02
#   ys=-6.981E-09  -gs= 3.767E-08 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     22    103      2     2     0   5.317D-02   6.023D+00
#   F =   6.0226944750315505
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.08194D+00    |proj g|=  4.84030D-02
#
# At iterate    5    f=  6.03549D+00    |proj g|=  1.16623D-02
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate   10    f=  6.03131D+00    |proj g|=  4.18420D-03
#   ys=-5.781E-06  -gs= 2.371E-07 BFGS update SKIPPED
#
# At iterate   15    f=  6.03120D+00    |proj g|=  4.89326D-02
#
# At iterate   20    f=  6.03118D+00    |proj g|=  4.87633D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     20     72      1     1     0   4.876D-02   6.031D+00
#   F =   6.0311817967123389
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.09906D+00    |proj g|=  5.85894D-02
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  6.05934D+00    |proj g|=  1.06052D-02
#
# At iterate   10    f=  6.05730D+00    |proj g|=  1.22696D-02
#
# At iterate   15    f=  6.05725D+00    |proj g|=  1.00396D-01
#   ys=-1.918E-06  -gs= 3.346E-08 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     17     71      1     1     0   1.035D-01   6.057D+00
#   F =   6.0572541313383379
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.11133D+00    |proj g|=  4.58091D-02
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  6.07129D+00    |proj g|=  1.23589D-02
#
# At iterate   10    f=  6.07012D+00    |proj g|=  8.68819D-03
#   ys=-2.475E-05  -gs= 3.789E-07 BFGS update SKIPPED
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   15    f=  6.06947D+00    |proj g|=  7.53326D-02
#
# At iterate   20    f=  6.06942D+00    |proj g|=  1.85111D-03
#
# At iterate   25    f=  6.06941D+00    |proj g|=  2.05946D-03
#
# At iterate   30    f=  6.06923D+00    |proj g|=  4.67937D-03
#
# At iterate   35    f=  6.06910D+00    |proj g|=  4.38148D-04
#
# At iterate   40    f=  6.06856D+00    |proj g|=  4.83995D-03
#
# At iterate   45    f=  6.06090D+00    |proj g|=  1.04458D-01
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate   50    f=  6.06056D+00    |proj g|=  1.41439D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50    162      2     1     0   1.414D-01   6.061D+00
#   F =   6.0605613766211768
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.15403D+00    |proj g|=  2.80349D-02
#
# At iterate    5    f=  6.11767D+00    |proj g|=  1.46999D-02
#
# At iterate   10    f=  6.11572D+00    |proj g|=  3.92871D-03
#
# At iterate   15    f=  6.11341D+00    |proj g|=  9.05679D-04
#
# At iterate   20    f=  6.11321D+00    |proj g|=  4.57044D-03
#
# At iterate   25    f=  6.10312D+00    |proj g|=  1.47391D-02
#
# At iterate   30    f=  6.09311D+00    |proj g|=  3.64688D-03
#   ys=-6.056E-06  -gs= 7.100E-07 BFGS update SKIPPED
#
# At iterate   35    f=  6.09238D+00    |proj g|=  8.85545D-03
#   ys=-1.138E-08  -gs= 1.969E-07 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     37     96      1     2     0   7.797D-02   6.092D+00
#   F =   6.0923803001871004
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.19358D+00    |proj g|=  2.76951D-02
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  6.18124D+00    |proj g|=  1.27959D-01
#
# At iterate   10    f=  6.18113D+00    |proj g|=  4.91913D-03
#
# At iterate   15    f=  6.18059D+00    |proj g|=  6.13555D-03
#
# At iterate   20    f=  6.15965D+00    |proj g|=  9.81458D-03
#
# At iterate   25    f=  6.15898D+00    |proj g|=  9.50996D-04
#
# At iterate   30    f=  6.15870D+00    |proj g|=  2.95786D-03
#
# At iterate   35    f=  6.15008D+00    |proj g|=  6.16199D-03
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   40    f=  6.14906D+00    |proj g|=  6.89117D-03
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     44    140      2     0     0   4.041D-02   6.149D+00
#   F =   6.1490473733825697
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.23261D+00    |proj g|=  4.20915D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8      2     10      1     0     0   2.395D-02   6.197D+00
#   F =   6.1970596147567267
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.27311D+00    |proj g|=  1.27461D-01
# ...
#   F =   6.1920854656298694
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.26639D+00    |proj g|=  1.03709D-01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  6.22457D+00    |proj g|=  7.53666D-03
#
# At iterate   10    f=  6.22388D+00    |proj g|=  1.06144D-02
#
# At iterate   15    f=  6.22236D+00    |proj g|=  2.70911D-03
#
# At iterate   20    f=  6.22232D+00    |proj g|=  2.87028D-03
#
# At iterate   25    f=  6.21470D+00    |proj g|=  1.61571D-02
#
# At iterate   30    f=  6.20423D+00    |proj g|=  3.05982D-03
#
# At iterate   35    f=  6.20394D+00    |proj g|=  6.27008D-03
#
# At iterate   40    f=  6.20314D+00    |proj g|=  1.20075D-03
#   ys=-3.752E-08  -gs= 1.215E-07 BFGS update SKIPPED
#
# At iterate   45    f=  6.20305D+00    |proj g|=  2.09733D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     46    108      1     1     0   2.097D-02   6.203D+00
#   F =   6.2030525336347617
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.29594D+00    |proj g|=  1.46594D-01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate    5    f=  6.23746D+00    |proj g|=  1.91862D-02
#
# At iterate   10    f=  6.23543D+00    |proj g|=  5.86621D-03
#
# At iterate   15    f=  6.23428D+00    |proj g|=  9.55806D-03
#
# At iterate   20    f=  6.23336D+00    |proj g|=  6.91242D-03
#
# At iterate   25    f=  6.23256D+00    |proj g|=  1.83395D-02
#
# At iterate   30    f=  6.21386D+00    |proj g|=  1.88120D-02
#
# At iterate   35    f=  6.21339D+00    |proj g|=  5.46918D-03
#
# At iterate   40    f=  6.21320D+00    |proj g|=  1.11499D-03
#
# At iterate   45    f=  6.21319D+00    |proj g|=  1.83951D-02
#   ys=-3.075E-06  -gs= 8.435E-08 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     48    116      2     1     0   1.790D-02   6.213D+00
#   F =   6.2131893277022989
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.35537D+00    |proj g|=  2.31943D-01
#
# At iterate    5    f=  6.24813D+00    |proj g|=  1.93704D-02
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate   10    f=  6.24639D+00    |proj g|=  1.67511D-02
#
# At iterate   15    f=  6.24486D+00    |proj g|=  1.31380D-02
#
# At iterate   20    f=  6.24395D+00    |proj g|=  1.48704D-03
#
# At iterate   25    f=  6.24389D+00    |proj g|=  5.17070D-03
#
# At iterate   30    f=  6.23367D+00    |proj g|=  4.46130D-02
#
# At iterate   35    f=  6.22359D+00    |proj g|=  8.16256D-03
#
# At iterate   40    f=  6.22319D+00    |proj g|=  5.49355D-03
#
# At iterate   45    f=  6.22309D+00    |proj g|=  2.25051D-03
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate   50    f=  6.22306D+00    |proj g|=  3.82913D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50     76      1     0     0   3.829D-04   6.223D+00
#   F =   6.2230606485728179
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.38267D+00    |proj g|=  2.51909D-01
#
# At iterate    5    f=  6.26182D+00    |proj g|=  1.91850D-02
#
# At iterate   10    f=  6.25992D+00    |proj g|=  5.44976D-03
#
# At iterate   15    f=  6.25907D+00    |proj g|=  1.55020D-02
#
# At iterate   20    f=  6.25778D+00    |proj g|=  3.65884D-03
#
# At iterate   25    f=  6.25752D+00    |proj g|=  4.00804D-03
#
# At iterate   30    f=  6.24436D+00    |proj g|=  3.80773D-02
#
# At iterate   35    f=  6.23472D+00    |proj g|=  1.81085D-03
#
# At iterate   40    f=  6.23466D+00    |proj g|=  1.40421D-04
#
# At iterate   45    f=  6.23463D+00    |proj g|=  1.54874D-03
#
# At iterate   50    f=  6.23378D+00    |proj g|=  1.24586D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50     65      1     0     0   1.246D-02   6.234D+00
#   F =   6.2337790209798483
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.47328D+00    |proj g|=  3.86897D-01
#
# At iterate    5    f=  6.27422D+00    |proj g|=  2.13552D-02
#
# At iterate   10    f=  6.27257D+00    |proj g|=  2.75981D-03
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     13     37      1     0     0   1.359D-02   6.272D+00
#   F =   6.2720563345666491
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.51849D+00    |proj g|=  4.51988D-01
#
# At iterate    5    f=  6.27874D+00    |proj g|=  1.14223D-02
#
# At iterate   10    f=  6.27798D+00    |proj g|=  1.70023D-03
#
# At iterate   15    f=  6.27751D+00    |proj g|=  4.02160D-03
#   ys=-6.590E-06  -gs= 7.955E-07 BFGS update SKIPPED
#
# At iterate   20    f=  6.27744D+00    |proj g|=  3.71620D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     21     72      1     1     0   3.716D-02   6.277D+00
#   F =   6.2774422281811919
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.57352D+00    |proj g|=  5.34583D-01
#
# At iterate    5    f=  6.28428D+00    |proj g|=  2.80844D-02
#
# At iterate   10    f=  6.28317D+00    |proj g|=  1.79981D-02
#
# At iterate   15    f=  6.28294D+00    |proj g|=  6.07681D-03
#
# At iterate   20    f=  6.28276D+00    |proj g|=  2.42514D-03
#
# At iterate   25    f=  6.28236D+00    |proj g|=  6.57676D-03
#
# At iterate   30    f=  6.26747D+00    |proj g|=  3.11110D-02
#
# At iterate   35    f=  6.26555D+00    |proj g|=  8.85776D-03
#
# At iterate   40    f=  6.26403D+00    |proj g|=  1.31029D-02
#
# At iterate   45    f=  6.26299D+00    |proj g|=  3.84920D-03
#
# At iterate   50    f=  6.26273D+00    |proj g|=  4.62484D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50     73      1     0     0   4.625D-03   6.263D+00
#   F =   6.2627294999483851
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.55169D+00    |proj g|=  5.27388D-01
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  6.29315D+00    |proj g|=  1.84881D-02
#
# At iterate   10    f=  6.29135D+00    |proj g|=  2.04645D-02
#   ys=-8.765E-09  -gs= 4.614E-08 BFGS update SKIPPED
#
# At iterate   15    f=  6.29130D+00    |proj g|=  2.97120D-03
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   20    f=  6.29121D+00    |proj g|=  3.25201D-03
#
# At iterate   25    f=  6.29121D+00    |proj g|=  3.78144D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     28    141      3     1     0   1.741D-02   6.291D+00
#   F =   6.2911992082937997
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
error_percent = np.mean(np.abs(df_model_商車.loc['2018-01-01 00:00:00':'2020-12-01 00:00:00','sum'] - ans_ans)/df_model_商車.loc['2018-01-01 00:00:00':'2020-12-01 00:00:00','sum'])

# %%
plt.plot(df_model_商車.loc['2018-01-01':'2020-12-01','sum'].index,df_model_商車.loc['2018-01-01':'2020-12-01','sum'],color = 'red')
plt.plot(df_model_商車.index[71:107],ans_ans,color = 'blue') #3
plt.scatter(df_model_商車.loc['2018-01-01':'2020-12-01','sum'].index,df_model_商車.loc['2018-01-01':'2020-12-01','sum'], color = 'red')
plt.scatter(df_model_商車.index[71:107],ans_ans,color = 'blue') #3
plt.legend(['actual','predict'])
plt.title('mape:'+str(error_percent.round(3)))
# Out:
# Text(0.5, 1.0, 'mape:0.114')

# %%
from sklearn.ensemble import RandomForestRegressor
X = df_model_商車.iloc[:,1:]
y = df_model_商車.iloc[:,0]
model = RandomForestRegressor(n_estimators=500, random_state=1)
model.fit(X, y)
a = list(zip(X.columns,model.feature_importances_))
a.sort(key = lambda x:x[1])
a
# Out:
# [('covid_sc_last_month', 0.0010219943981419882),
#  ('steel_sc_last_month', 0.007825191323161581),
#  ('steel_sc', 0.008190314034507293),
#  ('covid_sc', 0.009941206775195163),
#  ('economicgrowth_sc', 0.013942881281145294),
#  ('CPIT_sc', 0.01513075311930752),
#  ('signal_sc', 0.01517120848193903),
#  ('incomeaverage_sc_last_month', 0.01648981071384783),
#  ('oil_sc_last_month', 0.01882770254079843),
#  ('gdp_sc_last_month', 0.02018934318666707),
#  ('CPI_sc', 0.020236750006729812),
#  ('signal_sc_last_month', 0.020327572056138617),
#  ('oil_sc', 0.024928240403911277),
#  ('industry_sc_last_month', 0.02571727454808371),
#  ('economicgrowth_sc_last_month', 0.027447590576294225),
#  ('gdp_sc', 0.02873332754158681),
#  ('CPIT_sc_last_month', 0.033118182948078584),
#  ('lead_sc', 0.04041637677652652),
#  ('stock_sc_last_month', 0.04139393962618908),
#  ('lead_sc_last_month', 0.0415569446974592),
#  ('last_sell', 0.04960736062937871),
#  ('CPI_sc_last_month', 0.06752574345348203),
#  ('stock_sc', 0.06936465485805723),
#  ('incomeaverage_sc', 0.07519407958111957),
#  ('industry_sc', 0.3077015564422534)]

# %%
# 10210112
ans_ans = []
for x in range(70,len(df_model_商車.index)-1):  #4
    if x < 85:
        s = SARIMAX(
                    df_model_商車.loc[:df_model_商車.index[x],'sum'].astype(int).values,
                    order = (1,1,1),
                    seasonal_order=(0,1,1,12),
                    exog = df_model_商車.loc[:df_model_商車.index[x],[                                
                                        'CPI_sc_last_month',
                                        'stock_sc',
                                        'incomeaverage_sc',
                                        'industry_sc',
                                        'last_sell']].astype(float),
                    trend = 'n',
                    time_varying_regression=True,
                    mle_regression=False,
                    measurement_error = True,
                    enforce_stationary = False
                )
    else:
        s = SARIMAX(
                    df_model_商車.loc[df_model_商車.index[x-65]:df_model_商車.index[x],'sum'].astype(int).values,
                    order = (1,1,1),
                    seasonal_order=(1,1,2,12),
                    exog = df_model_商車.loc[df_model_商車.index[x-65]:df_model_商車.index[x],[                                
                                        'CPI_sc_last_month',
                                        'stock_sc',
                                        'incomeaverage_sc',
                                        'industry_sc',
                                        'last_sell']].astype(float),
                    trend = 'c',
                    time_varying_regression=False,
                    mle_regression=False,
                    measurement_error = True,
                    enforce_stationary = False
                )
    result = s.fit()
    ans = result.get_forecast(steps = 1, exog = df_model_商車.loc[df_model_商車.index[x+1],[
                                 'CPI_sc_last_month',
                                 'stock_sc_last_month',
                                 'incomeaverage_sc',
                                 'industry_sc',
                                 'last_sell']].astype(float))
    ans_ans.append(ans.predicted_mean.values[0])
# Out:
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.87548D+00    |proj g|=  7.00043D-01
#
# At iterate    5    f=  5.55139D+00    |proj g|=  7.31211D-02
#
# At iterate   10    f=  5.55074D+00    |proj g|=  4.69114D-02
#
# At iterate   15    f=  5.54575D+00    |proj g|=  6.39404D-02
#
# At iterate   20    f=  5.51567D+00    |proj g|=  8.21152D-02
#
# At iterate   25    f=  5.51389D+00    |proj g|=  2.16527D-02
#
# At iterate   30    f=  5.51383D+00    |proj g|=  6.60111D-04
#
# At iterate   35    f=  5.51355D+00    |proj g|=  1.97075D-02
#
# At iterate   40    f=  5.49551D+00    |proj g|=  1.92500D-01
#
# At iterate   45    f=  5.48677D+00    |proj g|=  2.52303D-01
#
# At iterate   50    f=  5.48413D+00    |proj g|=  1.11373D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     50     76      1     0     0   1.114D-01   5.484D+00
#   F =   5.4841341848343301
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.91936D+00    |proj g|=  6.82161D-01
#
# At iterate    5    f=  5.81709D+00    |proj g|=  6.45651D-03
#
# At iterate   10    f=  5.80798D+00    |proj g|=  1.92387D-01
#
# At iterate   15    f=  5.65538D+00    |proj g|=  9.06411D-01
#
# At iterate   20    f=  5.56406D+00    |proj g|=  3.73162D-02
#
# At iterate   25    f=  5.54194D+00    |proj g|=  5.56484D-01
#
# At iterate   30    f=  5.52598D+00    |proj g|=  4.30665D-01
#
# At iterate   35    f=  5.50873D+00    |proj g|=  7.90305D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   40    f=  5.50671D+00    |proj g|=  6.54188D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     43    132      2     0     0   7.674D-02   5.507D+00
#   F =   5.5067076379443076
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.95162D+00    |proj g|=  6.87071D-01
#
# At iterate    5    f=  5.65010D+00    |proj g|=  4.88151D-01
#
# At iterate   10    f=  5.58254D+00    |proj g|=  1.01060D-01
#
# At iterate   15    f=  5.58232D+00    |proj g|=  1.80788D-02
#
# At iterate   20    f=  5.57531D+00    |proj g|=  5.61300D-01
#
# At iterate   25    f=  5.56380D+00    |proj g|=  3.83686D-01
#
# At iterate   30    f=  5.55708D+00    |proj g|=  9.04222D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     32     76      1     0     0   7.942D-02   5.557D+00
#   F =   5.5570769684663039
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.98147D+00    |proj g|=  6.85869D-01
#
# At iterate    5    f=  5.66447D+00    |proj g|=  1.82354D-01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate   10    f=  5.62310D+00    |proj g|=  1.07489D+00
#
# At iterate   15    f=  5.60248D+00    |proj g|=  1.89349D-01
#
# At iterate   20    f=  5.59982D+00    |proj g|=  1.27962D-02
#
# At iterate   25    f=  5.59756D+00    |proj g|=  4.43969D-01
#
# At iterate   30    f=  5.58974D+00    |proj g|=  1.70724D-01
#
# At iterate   35    f=  5.58451D+00    |proj g|=  6.97584D-03
#
# At iterate   40    f=  5.58449D+00    |proj g|=  8.44007D-04
#
# At iterate   45    f=  5.58449D+00    |proj g|=  6.23907D-03
#
# At iterate   50    f=  5.58359D+00    |proj g|=  2.00516D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     50    102      1     0     0   2.005D-01   5.584D+00
#   F =   5.5835866463430097
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.01248D+00    |proj g|=  6.90782D-01
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.85011D+00    |proj g|=  9.35842D-02
#
# At iterate   10    f=  5.82110D+00    |proj g|=  5.54019D-01
#
# At iterate   15    f=  5.62124D+00    |proj g|=  1.03637D+00
#
# At iterate   20    f=  5.60496D+00    |proj g|=  1.59251D-02
#
# At iterate   25    f=  5.60487D+00    |proj g|=  2.22821D-02
#
# At iterate   30    f=  5.60460D+00    |proj g|=  2.13166D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     32     66      1     0     0   5.489D-02   5.605D+00
#   F =   5.6045998676542670
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.03946D+00    |proj g|=  6.94639D-01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.66020D+00    |proj g|=  9.97812D-02
#
# At iterate   10    f=  5.63162D+00    |proj g|=  7.38189D-02
#
# At iterate   15    f=  5.62587D+00    |proj g|=  3.13733D-01
#
# At iterate   20    f=  5.62249D+00    |proj g|=  2.16617D-02
#
# At iterate   25    f=  5.62235D+00    |proj g|=  3.59701D-03
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     28     76      1     0     0   7.606D-02   5.622D+00
#   F =   5.6223479679737505
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.06671D+00    |proj g|=  6.96945D-01
#
# At iterate    5    f=  5.65590D+00    |proj g|=  2.24695D-01
#
# At iterate   10    f=  5.65008D+00    |proj g|=  1.00384D-01
#
# At iterate   15    f=  5.64025D+00    |proj g|=  8.48009D-02
#
# At iterate   20    f=  5.61404D+00    |proj g|=  6.92977D-01
#
# At iterate   25    f=  5.60238D+00    |proj g|=  1.91945D-01
#
# At iterate   30    f=  5.60136D+00    |proj g|=  1.93056D-02
#
# At iterate   35    f=  5.60114D+00    |proj g|=  7.71095D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     36     93      1     0     0   7.711D-02   5.601D+00
#   F =   5.6011352284153073
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.09066D+00    |proj g|=  7.03298D-01
#
# At iterate    5    f=  5.66795D+00    |proj g|=  8.32902D-01
#
# At iterate   10    f=  5.65407D+00    |proj g|=  8.40726D-03
#
# At iterate   15    f=  5.65386D+00    |proj g|=  1.66499D-02
#
# At iterate   20    f=  5.65070D+00    |proj g|=  1.06759D-01
#
# At iterate   25    f=  5.62157D+00    |proj g|=  3.32808D-02
#
# At iterate   30    f=  5.61823D+00    |proj g|=  2.06439D-03
#
# At iterate   35    f=  5.61821D+00    |proj g|=  2.80418D-02
#
# At iterate   40    f=  5.61679D+00    |proj g|=  9.60829D-02
#
# At iterate   45    f=  5.59484D+00    |proj g|=  2.87620D-01
#
# At iterate   50    f=  5.59126D+00    |proj g|=  3.74726D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     50     96      1     0     0   3.747D-02   5.591D+00
#   F =   5.5912645199042572
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.11569D+00    |proj g|=  7.09588D-01
#
# At iterate    5    f=  5.69676D+00    |proj g|=  1.26181D-01
#
# At iterate   10    f=  5.66238D+00    |proj g|=  1.08179D-02
#
# At iterate   15    f=  5.63893D+00    |proj g|=  1.11609D-01
#
# At iterate   20    f=  5.63206D+00    |proj g|=  2.48550D-02
#
# At iterate   25    f=  5.63191D+00    |proj g|=  5.17833D-03
#
# At iterate   30    f=  5.63189D+00    |proj g|=  1.31687D-02
#
# At iterate   35    f=  5.63117D+00    |proj g|=  1.46038D-01
#
# At iterate   40    f=  5.61406D+00    |proj g|=  3.01366D-01
#
# At iterate   45    f=  5.60223D+00    |proj g|=  2.41624D-02
#
# At iterate   50    f=  5.60124D+00    |proj g|=  1.46588D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     50     69      1     0     0   1.466D-03   5.601D+00
#   F =   5.6012387917854713
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.14028D+00    |proj g|=  7.09677D-01
#
# At iterate    5    f=  5.69205D+00    |proj g|=  2.88907D-01
#
# At iterate   10    f=  5.68409D+00    |proj g|=  4.61304D-03
#
# At iterate   15    f=  5.66019D+00    |proj g|=  6.98734D-01
#
# At iterate   20    f=  5.65458D+00    |proj g|=  1.75848D-03
#
# At iterate   25    f=  5.65456D+00    |proj g|=  2.61277D-03
#
# At iterate   30    f=  5.65302D+00    |proj g|=  1.50475D-01
#
# At iterate   35    f=  5.63678D+00    |proj g|=  5.65443D-02
#
# At iterate   40    f=  5.62053D+00    |proj g|=  1.38046D-02
#
# At iterate   45    f=  5.62053D+00    |proj g|=  3.19620D-01
#   ys=-5.943E-10  -gs= 2.183E-07 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     46    111      1     1     0   3.196D-01   5.621D+00
#   F =   5.6205292445973809
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.16786D+00    |proj g|=  7.12667D-01
#
# At iterate    5    f=  5.70734D+00    |proj g|=  5.25356D-02
#
# At iterate   10    f=  5.69905D+00    |proj g|=  1.28555D-02
#
# At iterate   15    f=  5.67210D+00    |proj g|=  8.28180D-02
#
# At iterate   20    f=  5.66947D+00    |proj g|=  1.27053D-02
#
# At iterate   25    f=  5.66945D+00    |proj g|=  1.08550D-02
#
# At iterate   30    f=  5.65066D+00    |proj g|=  2.44712D-01
#
# At iterate   35    f=  5.64829D+00    |proj g|=  7.32207D-02
#
# At iterate   40    f=  5.63494D+00    |proj g|=  2.64673D-02
#
# At iterate   45    f=  5.63479D+00    |proj g|=  5.58198D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     46     83      1     0     0   5.560D-04   5.635D+00
#   F =   5.6347882331959136
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.19193D+00    |proj g|=  7.15278D-01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.71635D+00    |proj g|=  3.49595D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10      5     27      1     0     0   3.496D-01   5.716D+00
#   F =   5.7163452144428879
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.21467D+00    |proj g|=  7.18488D-01
#
# At iterate    5    f=  5.73361D+00    |proj g|=  2.22044D-01
#
# At iterate   10    f=  5.73190D+00    |proj g|=  1.90066D-02
#
# At iterate   15    f=  5.71849D+00    |proj g|=  1.56377D-01
#
# At iterate   20    f=  5.70423D+00    |proj g|=  7.41499D-02
#
# At iterate   25    f=  5.70066D+00    |proj g|=  7.52375D-03
#
# At iterate   30    f=  5.70062D+00    |proj g|=  9.67376D-03
#
# At iterate   35    f=  5.69963D+00    |proj g|=  2.16847D-01
#
# At iterate   40    f=  5.68289D+00    |proj g|=  4.96413D-02
#
# At iterate   45    f=  5.66954D+00    |proj g|=  1.22197D-01
#
# At iterate   50    f=  5.66880D+00    |proj g|=  1.34729D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     50    100      1     0     0   1.347D-03   5.669D+00
#   F =   5.6687983127761994
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.23447D+00    |proj g|=  7.23871D-01
#
# At iterate    5    f=  5.74014D+00    |proj g|=  3.10161D-01
#
# At iterate   10    f=  5.73417D+00    |proj g|=  4.35357D-01
#
# At iterate   15    f=  5.71296D+00    |proj g|=  1.11377D-01
#
# At iterate   20    f=  5.71289D+00    |proj g|=  7.39716D-04
#
# At iterate   25    f=  5.71288D+00    |proj g|=  9.89833D-03
#
# At iterate   30    f=  5.71246D+00    |proj g|=  1.12790D-01
#
# At iterate   35    f=  5.70992D+00    |proj g|=  2.25665D-02
#
# At iterate   40    f=  5.69283D+00    |proj g|=  5.47304D-01
#
# At iterate   45    f=  5.68093D+00    |proj g|=  6.76841D-03
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate   50    f=  5.68071D+00    |proj g|=  4.65011D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     50     74      1     0     0   4.650D-04   5.681D+00
#   F =   5.6807134973404017
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.25972D+00    |proj g|=  7.25531D-01
#
# At iterate    5    f=  5.76210D+00    |proj g|=  2.62176D-01
#
# At iterate   10    f=  5.75297D+00    |proj g|=  6.88829D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     10     26      1     0     0   6.888D-02   5.753D+00
#   F =   5.7529739966804616
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.49032D+00    |proj g|=  3.51541D-01
#
# At iterate    5    f=  5.36979D+00    |proj g|=  1.39408D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   10    f=  5.36965D+00    |proj g|=  6.18240D-03
#
# At iterate   15    f=  5.36963D+00    |proj g|=  1.96886D-03
#
# At iterate   20    f=  5.36749D+00    |proj g|=  1.60983D-02
#
# At iterate   25    f=  5.36505D+00    |proj g|=  4.85806D-02
#
# At iterate   30    f=  5.36503D+00    |proj g|=  5.25749D-02
#   ys=-2.913E-07  -gs= 3.107E-08 BFGS update SKIPPED
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     31    130      2     1     0   5.257D-02   5.365D+00
#   F =   5.3650303416875138
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.44412D+00    |proj g|=  3.44779D-01
#
# At iterate    5    f=  5.33261D+00    |proj g|=  2.69179D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   10    f=  5.32805D+00    |proj g|=  1.12882D-02
#
# At iterate   15    f=  5.32392D+00    |proj g|=  9.39032D-04
#
# At iterate   20    f=  5.32258D+00    |proj g|=  1.16554D-02
#
# At iterate   25    f=  5.32160D+00    |proj g|=  9.92799D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   30    f=  5.32135D+00    |proj g|=  1.26307D-02
#
# At iterate   35    f=  5.32134D+00    |proj g|=  4.59388D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   40    f=  5.32132D+00    |proj g|=  9.48603D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     42    199      4     0     0   3.840D-02   5.321D+00
#   F =   5.3213225142303253
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.46981D+00    |proj g|=  3.43771D-01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.34796D+00    |proj g|=  4.42997D-02
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8      7     32      1     0     0   3.843D-02   5.343D+00
#   F =   5.3430089437810224
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.43420D+00    |proj g|=  3.43765D-01
#
# At iterate    5    f=  5.31562D+00    |proj g|=  2.52204D-02
#
# At iterate   10    f=  5.30913D+00    |proj g|=  1.38841D-02
#   ys=-3.070E-06  -gs= 2.320E-07 BFGS update SKIPPED
#
# At iterate   15    f=  5.30711D+00    |proj g|=  3.94923D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     16     48      1     1     0   3.949D-02   5.307D+00
#   F =   5.3071119818485961
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.45230D+00    |proj g|=  3.24853D-01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.34630D+00    |proj g|=  1.19798D-02
#
# At iterate   10    f=  5.34250D+00    |proj g|=  1.45003D-02
#
# At iterate   15    f=  5.34083D+00    |proj g|=  7.37746D-04
#
# At iterate   20    f=  5.34060D+00    |proj g|=  1.49647D-03
#
# At iterate   25    f=  5.30163D+00    |proj g|=  1.55692D-02
#
# At iterate   30    f=  5.29491D+00    |proj g|=  4.13287D-03
#
# At iterate   35    f=  5.29481D+00    |proj g|=  1.64551D-03
#
# At iterate   40    f=  5.29476D+00    |proj g|=  5.30801D-04
#
# At iterate   45    f=  5.29475D+00    |proj g|=  9.58367D-04
#
# At iterate   50    f=  5.29468D+00    |proj g|=  1.40750D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50     75      1     0     0   1.407D-03   5.295D+00
#   F =   5.2946812099851659
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.50910D+00    |proj g|=  2.96996D-01
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.40562D+00    |proj g|=  8.13570D-03
#
# At iterate   10    f=  5.40071D+00    |proj g|=  5.48949D-03
#
# At iterate   15    f=  5.39996D+00    |proj g|=  5.14337D-03
#
# At iterate   20    f=  5.39914D+00    |proj g|=  4.17603D-03
#
# At iterate   25    f=  5.39835D+00    |proj g|=  4.10459D-03
#
# At iterate   30    f=  5.39653D+00    |proj g|=  2.83667D-03
#
# At iterate   35    f=  5.39223D+00    |proj g|=  1.41656D-02
#
# At iterate   40    f=  5.38850D+00    |proj g|=  2.63495D-03
#
# At iterate   45    f=  5.38785D+00    |proj g|=  2.91428D-03
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate   50    f=  5.37172D+00    |proj g|=  1.91767D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50     67      1     0     0   1.918D-02   5.372D+00
#   F =   5.3717202701986748
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.51525D+00    |proj g|=  2.93386D-01
#
# At iterate    5    f=  5.41749D+00    |proj g|=  9.19099D-03
#
# At iterate   10    f=  5.41429D+00    |proj g|=  1.68770D-02
#
# At iterate   15    f=  5.41171D+00    |proj g|=  4.68001D-03
#
# At iterate   20    f=  5.41139D+00    |proj g|=  3.32305D-03
#
# At iterate   25    f=  5.41090D+00    |proj g|=  5.65228D-03
#
# At iterate   30    f=  5.40961D+00    |proj g|=  2.70800D-03
#
# At iterate   35    f=  5.40588D+00    |proj g|=  1.36405D-02
#
# At iterate   40    f=  5.40246D+00    |proj g|=  1.40695D-02
#
# At iterate   45    f=  5.39604D+00    |proj g|=  2.90484D-03
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate   50    f=  5.39586D+00    |proj g|=  6.81830D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50    101      1     0     0   6.818D-03   5.396D+00
#   F =   5.3958638049541916
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.49880D+00    |proj g|=  2.62588D-01
#
# At iterate    5    f=  5.41347D+00    |proj g|=  9.71220D-03
#
# At iterate   10    f=  5.41231D+00    |proj g|=  3.26042D-03
#
# At iterate   15    f=  5.41205D+00    |proj g|=  5.56395D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   20    f=  5.41201D+00    |proj g|=  1.67658D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     24    163      2     0     0   5.318D-02   5.412D+00
#   F =   5.4119986170296741
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.51576D+00    |proj g|=  2.84847D-01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.41857D+00    |proj g|=  6.61957D-03
#
# At iterate   10    f=  5.41751D+00    |proj g|=  6.01651D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     13     42      1     0     0   6.130D-02   5.417D+00
#   F =   5.4174039006961756
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.53641D+00    |proj g|=  2.89007D-01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.43254D+00    |proj g|=  6.71408D-03
#
# ...
#
# At iterate   30    f=  5.44989D+00    |proj g|=  1.33037D-01
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     31    159      3     1     0   1.330D-01   5.450D+00
#   F =   5.4498943112778040
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.51668D+00    |proj g|=  1.67140D-01
#
# At iterate    5    f=  5.44929D+00    |proj g|=  1.07893D-02
#
# At iterate   10    f=  5.44832D+00    |proj g|=  2.09882D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     14     46      1     0     0   1.135D-01   5.448D+00
#   F =   5.4480622929491567
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.51533D+00    |proj g|=  1.69279D-01
#
# At iterate    5    f=  5.44828D+00    |proj g|=  2.49777D-02
#
# At iterate   10    f=  5.44480D+00    |proj g|=  2.28198D-03
#
# At iterate   15    f=  5.44453D+00    |proj g|=  3.29612D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     15     41      1     0     0   3.296D-02   5.445D+00
#   F =   5.4445253393192878
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.51718D+00    |proj g|=  1.51944D-01
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.45246D+00    |proj g|=  3.69119D-02
#
# At iterate   10    f=  5.44161D+00    |proj g|=  1.02379D-02
#
# At iterate   15    f=  5.44119D+00    |proj g|=  2.88566D-03
#
# At iterate   20    f=  5.44104D+00    |proj g|=  2.47581D-03
#
# At iterate   25    f=  5.43033D+00    |proj g|=  3.55051D-02
#
# At iterate   30    f=  5.42046D+00    |proj g|=  4.80241D-03
#
# At iterate   35    f=  5.41980D+00    |proj g|=  2.96601D-04
#
# At iterate   40    f=  5.41967D+00    |proj g|=  4.22060D-03
#
# At iterate   45    f=  5.41711D+00    |proj g|=  1.00581D-02
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate   50    f=  5.41641D+00    |proj g|=  1.39004D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     50     57      1     0     0   1.390D-03   5.416D+00
#   F =   5.4164122746705736
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.52053D+00    |proj g|=  1.91468D-01
#
# At iterate    5    f=  5.43460D+00    |proj g|=  1.73810D-02
#
# At iterate   10    f=  5.43033D+00    |proj g|=  7.06303D-03
#
# At iterate   15    f=  5.43019D+00    |proj g|=  3.82921D-03
#   ys=-8.683E-11  -gs= 1.686E-07 BFGS update SKIPPED
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   20    f=  5.43001D+00    |proj g|=  7.38591D-02
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     21    124      3     1     0   7.386D-02   5.430D+00
#   F =   5.4300120537807670
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.51914D+00    |proj g|=  2.10852D-01
#
# At iterate    5    f=  5.44160D+00    |proj g|=  1.92712D-02
#
# At iterate   10    f=  5.43757D+00    |proj g|=  3.18087D-02
#
# At iterate   15    f=  5.43660D+00    |proj g|=  6.10563D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     17     48      1     0     0   2.085D-02   5.437D+00
#   F =   5.4365963977397351
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.56013D+00    |proj g|=  2.20945D-01
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
# At iterate    5    f=  5.47126D+00    |proj g|=  2.36922D-02
#
# At iterate   10    f=  5.47066D+00    |proj g|=  1.20738D-03
#
# At iterate   15    f=  5.47046D+00    |proj g|=  4.16914D-04
#
# At iterate   20    f=  5.47032D+00    |proj g|=  4.92201D-03
#
# At iterate   25    f=  5.46163D+00    |proj g|=  2.96614D-02
#
# At iterate   30    f=  5.45713D+00    |proj g|=  6.51157D-03
#
# At iterate   35    f=  5.45650D+00    |proj g|=  1.32556D-02
#
# At iterate   40    f=  5.45592D+00    |proj g|=  9.96597D-04
#   ys=-4.344E-06  -gs= 1.699E-08 BFGS update SKIPPED
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     44     88      1     1     0   6.381D-02   5.456D+00
#   F =   5.4558871938831999
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.54431D+00    |proj g|=  2.61307D-01
#
# At iterate    5    f=  5.43231D+00    |proj g|=  2.67600D-02
#
# At iterate   10    f=  5.42889D+00    |proj g|=  1.46334D-03
#
# At iterate   15    f=  5.42853D+00    |proj g|=  1.15090D-03
#
# At iterate   20    f=  5.42843D+00    |proj g|=  3.09552D-03
#
# At iterate   25    f=  5.42268D+00    |proj g|=  2.62053D-03
#
# At iterate   30    f=  5.42220D+00    |proj g|=  1.87396D-03
#
# At iterate   35    f=  5.41902D+00    |proj g|=  1.34110D-02
#   ys=-1.942E-04  -gs= 8.261E-04 BFGS update SKIPPED
#
# At iterate   40    f=  5.41789D+00    |proj g|=  1.66458D-02
#
# At iterate   45    f=  5.41660D+00    |proj g|=  1.72295D-01
#   ys=-1.070E-04  -gs= 5.145E-07 BFGS update SKIPPED
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/xuzhejia/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     49    117      1     2     0   1.760D-01   5.417D+00
#   F =   5.4165889986695968
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.46520D+00    |proj g|=  1.94611D-01
#
# At iterate    5    f=  5.39159D+00    |proj g|=  1.61446D-02
#
# At iterate   10    f=  5.38865D+00    |proj g|=  4.12519D-03
#   ys=-7.337E-04  -gs= 9.715E-05 BFGS update SKIPPED
#
# At iterate   15    f=  5.38797D+00    |proj g|=  8.37701D-04
#
# At iterate   20    f=  5.38796D+00    |proj g|=  5.58641D-02
#   ys=-1.135E-07  -gs= 1.380E-07 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8     21     74      1     2     0   5.586D-02   5.388D+00
#   F =   5.3879613236855990
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.

# %%
error_percent = np.mean(np.abs(df_model_商車.loc['2018-01-01 00:00:00':'2020-12-01 00:00:00','sum'] - ans_ans)/df_model_商車.loc['2018-01-01 00:00:00':'2020-12-01 00:00:00','sum'])

# %%
plt.plot(df_model_商車.loc['2018-01-01':'2020-12-01','sum'].index,df_model_商車.loc['2018-01-01':'2020-12-01','sum'],color = 'red')
plt.plot(df_model_商車.index[71:107],ans_ans,color = 'blue') #3
plt.scatter(df_model_商車.loc['2018-01-01':'2020-12-01','sum'].index,df_model_商車.loc['2018-01-01':'2020-12-01','sum'], color = 'red')
plt.scatter(df_model_商車.index[71:107],ans_ans,color = 'blue') #3
plt.legend(['actual','predict'])
plt.title('mape:'+str(error_percent.round(3)))
# Out:
# Text(0.5, 1.0, 'mape:0.086')

# %%
df_model_商車.index[91]
# Out:
# Timestamp('2019-09-01 00:00:00')
