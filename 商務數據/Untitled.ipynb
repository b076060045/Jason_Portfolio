# %%
import pandas as pd

# %%
a = pd.read_csv(r'/Users/xuzhejia/Desktop/商務數據/整理後資料集_前段.csv',encoding='big5')
b = pd.read_csv(r'/Users/xuzhejia/Desktop/商務數據/整理後資料集_後段.csv',encoding='big5')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/_0/d81h2sdj5z1b6t7hh803swth0000gn/T/ipykernel_12083/2264082342.py in <module>
# ----> 1 a = pd.read_csv(r'/Users/xuzhejia/Desktop/商務數據/整理後資料集_前段.csv',encoding='big5')
#       2 b = pd.read_csv(r'/Users/xuzhejia/Desktop/商務數據/整理後資料集_後段.csv',encoding='big5')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data = pd.concat([a,b],ignore_index=True)
data
# Out:
#          Unnamed: 0  Unnamed: 0_x   å¹´  æ  æ¬        åç  ç¢å°  \
# 0                 0             0  2012    3    1          AUDI  é²å£
# 1                 1             0  2012    3    1          AUDI  é²å£
# 2                 2             0  2012    3    1          AUDI  é²å£
# 3                 3             0  2012    3    1          AUDI  é²å£
# 4                 4             0  2012    3    1          AUDI  é²å£
# ...             ...           ...   ...  ...  ...           ...     ...
# 1413603     1413603        128208  2021    2    6  æ±é¢¨å°åº·  åç¢
# 1413604     1413604        128208  2021    2    6  æ±é¢¨å°åº·  åç¢
# 1413605     1413605        128208  2021    2    6  æ±é¢¨å°åº·  åç¢
# 1413606     1413606        128208  2021    2    6  æ±é¢¨å°åº·  åç¢
# 1413607     1413607        128208  2021    2    6  æ±é¢¨å°åº·  åç¢
#
#         åéäºãå¤§åé åéä¸ãRVä¸ç´°åã  ç°¡è»å  ...  \
# ...
